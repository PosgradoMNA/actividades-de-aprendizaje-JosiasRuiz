# %% [markdown]
# # Practica W2
# **Josías Ruiz - A00968460**

# %% [markdown]
# ***Mod 4***

# %% [markdown]
# ![W2-M4.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
'''
The two arguments for this function are the files:
    - currentMem: File containing list of current members
    - exMem: File containing list of old members
    
    This function should remove all rows from currentMem containing 'no' 
    in the 'Active' column and appends them to exMem.
    '''
def cleanFiles(currentMem, exMem):  
    with open(currentMem,'r+') as readfile:#TODO: Open the exMem file in r+ mode
        members = readfile.readlines() #TODO: Read each member in the currentMem (1 member per row) file into a list.
    
    with open(exMem,'a+') as appendfile:#TODO: Open the exMem file in a+ mode        
        with open(currentMem,'w+') as writefile: #TODO: Open the exMem file in w+ mode
            header=members[0]
            members.pop(0)
            # Hint: Recall that the first line in the file is the header.
            
            inactive=[]  #TODO: iterate through the members and create a new list of the innactive members
            for member in members:
                if 'no' in member:
                    inactive.append(member)
           
            writefile.seek(0) # Go to the beginning of the currentMem file
            writefile.write(header)
            
            for member in members:  # TODO: Iterate through the members list. 
                if (member in inactive):   # If a member is inactive, add them to exMem, otherwise write them into currentMem
                    appendfile.write(member)
                else:
                    writefile.write(member)            
    
   #pass # Remove this line when done implementation


# The code below is to help you view the files.
# Do not modify this code for this exercise.
memReg = 'members.txt'
exReg = 'inactive.txt'
cleanFiles(memReg,exReg)


headers = "Membership No  Date Joined  Active  \n"
with open(memReg,'r') as readFile:
    print("Active Members: \n\n")
    print(readFile.read())
    
with open(exReg,'r') as readFile:
    print("Inactive Members: \n\n")
    print(readFile.read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-cfdd03b5ee78> in <module>
#      38 memReg = 'members.txt'
#      39 exReg = 'inactive.txt'
# ---> 40 cleanFiles(memReg,exReg)
#      41
#      42
#
# <ipython-input-3-cfdd03b5ee78> in cleanFiles(currentMem, exMem)
#       8     '''
#       9 def cleanFiles(currentMem, exMem):
# ---> 10     with open(currentMem,'r+') as readfile:#TODO: Open the exMem file in r+ mode
#      11         members = readfile.readlines() #TODO: Read each member in the currentMem (1 member per row) file into a list.
#      12
#
# FileNotFoundError: [Errno 2] No such file or directory: 'members.txt'

# %%
import pandas as banana

df=banana.DataFrame({'a':[11,21,31],'b':[21,22,23]})

df.head()
# Out:
#     a   b
# 0  11  21
# 1  21  22
# 2  31  23

# %%
q = df[['Rating']]
q

# %%
q = df[['Released','Artist']]
q

# %%
df.iloc[1,2]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-cc0bbd58fc38> in <module>
# ----> 1 df.iloc[1,2]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1504     def _getitem_tuple(self, tup: tuple):
#    1505
# -> 1506         self._has_valid_tuple(tup)
#    1507         with suppress(IndexingError):
#    1508             return self._getitem_lowerdim(tup)
#
# ...

# %%
new_index=['a','b','c','d','e','f','g','h']
df_new=df
df_new.index=new_index
df_new.loc['a', 'Artist']
df_new.loc['a':'d', 'Artist']
